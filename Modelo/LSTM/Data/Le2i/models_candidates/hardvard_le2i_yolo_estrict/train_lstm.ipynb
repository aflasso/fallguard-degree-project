# %% [markdown]
# # Entrenamiento LSTM — Detección de Caídas LE2I
# **Pipeline:** YOLOv11 → MediaPipe → LSTM
# **Dataset:** LE2I DIJON UMR6306
# **Clases:** `-1` normal · `0` caída · `1` post-caída

# %%
# %% [markdown]
# ## 0. Construcción de secuencias
# Corre esta celda para regenerar los datos sin necesidad de ejecutar `build_sequences.py` por separado.
# Cambia `FEATURE_MODE` para experimentar con distintas combinaciones de features.

# %%
import numpy as np
import pandas as pd
from pathlib import Path

# ── Configuración de datos ─────────────────────────────────────────────────────
KEYPOINTS_DIRS = [
    "Coffee_room/keypoints_yolo/",   # agrega o quita carpetas aquí
    "Home_room/keypoints_yolo/",
    "Fall_vision/f_raw_s_1/keypoints",
    # "Urfall/keypoints"
    # "Office/keypoints_tunned",
    # "Lecture_room/keypoints_tunned",
]
DATA_DIR   = Path("./lstm_data")
WINDOW     = 40    # frames por ventana
STRIDE     = 15    # stride entre ventanas
MIN_VALID  = 0.7   # fracción mínima de frames con keypoints válidos
MAX_FALL_RATIO = None

# ── Selector de features ───────────────────────────────────────────────────────
# Todos los 33 puntos MediaPipe:
#   "full"        → x,y,z,vis         (132 features)
#   "xy"          → x,y               ( 66 features)
#   "xyz"         → x,y,z             ( 99 features)
#   "xy_vel"      → x,y + vel x,y     (132 features)
#   "full_vel"    → x,y,z,vis + vel   (198 features)
# Solo 17 puntos COCO (equivalente a YOLO-pose):
#   "coco"        → x,y,z,vis         ( 68 features)
#   "coco_xy"     → x,y               ( 34 features)
#   "coco_vel"    → x,y,z,vis + vel   (136 features)
#   "coco_xy_vel"        → x,y + vel x,y              ( 68 features)
#   "coco_xy_vel_angles" → x,y + vel x,y + 8 ángulos  ( 73 features)
FEATURE_MODE = "coco_xy_vel"

# ──────────────────────────────────────────────────────────────────────────────

N_LANDMARKS = 33
ALL_DIMS    = ("x", "y", "z", "vis")
ALL_KP_COLS = [f"kp_{i}_{dim}" for i in range(N_LANDMARKS) for dim in ALL_DIMS]

# Índices de los 17 puntos COCO en MediaPipe
# (equivalentes a los keypoints de YOLO-pose)
COCO_INDICES = [0, 1, 2, 7, 8, 11, 12, 13, 14, 15, 16, 23, 24, 25, 26, 27, 28]

def get_feature_cols(mode):
    if mode == "xy":
        return [f"kp_{i}_{d}" for i in range(N_LANDMARKS) for d in ("x", "y")]
    elif mode == "xyz":
        return [f"kp_{i}_{d}" for i in range(N_LANDMARKS) for d in ("x", "y", "z")]
    elif mode == "coco":
        return [f"kp_{i}_{d}" for i in COCO_INDICES for d in ("x", "y", "z", "vis")]
    elif mode == "coco_xy":
        return [f"kp_{i}_{d}" for i in COCO_INDICES for d in ("x", "y")]
    elif mode == "coco_vel":
        return [f"kp_{i}_{d}" for i in COCO_INDICES for d in ("x", "y", "z", "vis")]
    elif mode in ("coco_xy_vel", "coco_xy_vel_angles"):
        return [f"kp_{i}_{d}" for i in COCO_INDICES for d in ("x", "y")]
    else:  # "full", "xy_vel", "full_vel"
        return ALL_KP_COLS

def add_velocity(window_kps, mode):
    """Agrega velocidad (diferencia entre frames consecutivos) a los features."""
    if "vel" not in mode:
        return window_kps
    # Calcular velocidad para las columnas x,y
    feat_cols = get_feature_cols(mode)
    xy_col_idx = [i for i, c in enumerate(feat_cols) if c.endswith("_x") or c.endswith("_y")]
    xy = window_kps[:, xy_col_idx]
    vel = np.zeros_like(xy)
    vel[1:] = xy[1:] - xy[:-1]
    return np.concatenate([window_kps, vel], axis=1)

# Ángulos relevantes para detección de caídas
# Cada ángulo definido por 3 puntos (A, B, C) donde B es el vértice
# Índices MediaPipe
ANGLE_TRIPLETS = [
    # Ángulos robustos al ángulo de cámara — relaciones verticales del cuerpo
    ("trunk_lean",     11,  12,  24),  # hombro_izq - hombro_der - cadera_der
    ("spine_angle",     0,  12,  24),  # nariz - hombro_der - cadera_der
    ("head_hip_left",   0,  11,  23),  # nariz - hombro_izq - cadera_izq
    ("head_hip_right",  0,  12,  24),  # nariz - hombro_der - cadera_der
    ("hip_symmetry",   23,  24,  26),  # cadera_izq - cadera_der - rodilla_der
]

def add_angles(window_kps, df_window):
    """Versión vectorizada — calcula todos los ángulos de una vez."""
    angles = np.zeros((len(window_kps), len(ANGLE_TRIPLETS)), dtype=np.float32)
    
    for j, (name, a, b, c) in enumerate(ANGLE_TRIPLETS):
        ax = df_window[f"kp_{a}_x"].values
        ay = df_window[f"kp_{a}_y"].values
        bx = df_window[f"kp_{b}_x"].values
        by = df_window[f"kp_{b}_y"].values
        cx = df_window[f"kp_{c}_x"].values
        cy = df_window[f"kp_{c}_y"].values

        v1x, v1y = ax - bx, ay - by
        v2x, v2y = cx - bx, cy - by

        norm1 = np.sqrt(v1x**2 + v1y**2)
        norm2 = np.sqrt(v2x**2 + v2y**2)

        valid = (norm1 > 0) & (norm2 > 0)
        dot   = v1x * v2x + v1y * v2y

        cos_angle = np.where(valid, np.clip(dot / (norm1 * norm2 + 1e-8), -1.0, 1.0), 0.0)
        angles[:, j] = np.where(valid, np.degrees(np.arccos(cos_angle)), 0.0)

    angles = angles / 180.0
    return np.concatenate([window_kps, angles], axis=1)
def interpolate_nans(window):
    result = window.copy()
    for col in range(result.shape[1]):
        col_data = result[:, col]
        nan_mask = np.isnan(col_data)
        if not nan_mask.any():
            continue
        if nan_mask.all():
            result[:, col] = 0.0
            continue
        indices   = np.arange(len(col_data))
        valid_idx = indices[~nan_mask]
        valid_val = col_data[~nan_mask]
        result[:, col] = np.interp(indices, valid_idx, valid_val)
    return result

def majority_label(labels):
    values, counts = np.unique(labels, return_counts=True)
    return int(values[counts.argmax()])

def valid_frame_ratio(window_kps):
    return (~np.isnan(window_kps[:, 0])).mean()

def build_sequences_from_df(df, window, stride, min_valid, video_name, feat_cols, mode):
    kp_values    = df[feat_cols].values.astype(np.float32)
    label_values = df["label"].values.astype(np.int8)
    frame_nums   = df["frame"].values

    sequences, labels, meta = [], [], []
    T = len(df)

    for start in range(0, T - window + 1, stride):
        end = start + window
        window_kps    = kp_values[start:end]
        window_labels = label_values[start:end]
        window_frames = frame_nums[start:end]

        if valid_frame_ratio(window_kps) < min_valid:
            continue

        window_kps = interpolate_nans(window_kps)
        window_kps = add_velocity(window_kps, mode)

        if "angles" in mode:
            df_window = df.iloc[start:end].reset_index(drop=True)
            window_kps = add_angles(window_kps, df_window)

        label = majority_label(window_labels)
        sequences.append(window_kps)
        labels.append(label)
        meta.append({
            "video":        video_name,
            "frame_inicio": int(window_frames[0]),
            "frame_fin":    int(window_frames[-1]),
            "label":        label,
        })
    return sequences, labels, meta


# ── Procesar todos los CSVs ────────────────────────────────────────────────────
feat_cols = get_feature_cols(FEATURE_MODE)
DATA_DIR.mkdir(parents=True, exist_ok=True)

csv_files = []
for kdir in KEYPOINTS_DIRS:
    csv_files.extend(sorted(Path(kdir).glob("*.csv")))

if not csv_files:
    raise FileNotFoundError(f"No se encontraron CSVs en: {KEYPOINTS_DIRS}")

all_sequences, all_labels, all_meta = [], [], []

for csv_path in csv_files:
    df = pd.read_csv(csv_path).sort_values("frame").reset_index(drop=True)
    video_name = f"{csv_path.parent.parent.name}/{csv_path.stem}"
    seqs, labs, meta = build_sequences_from_df(
        df, WINDOW, STRIDE, MIN_VALID, video_name, feat_cols, FEATURE_MODE
    )
    n0, n1, n2 = labs.count(-1), labs.count(0), labs.count(1)
    print(f"  {csv_path.name:30s} → {len(seqs):4d} ventanas  (-1:{n0:3d} 0:{n1:3d} 1:{n2:3d})")
    all_sequences.extend(seqs)
    all_labels.extend(labs)
    all_meta.extend(meta)

if MAX_FALL_RATIO is not None:
    import random
    random.seed(42)

    idx_normal  = [i for i, l in enumerate(all_labels) if l == -1]
    idx_fall    = [i for i, l in enumerate(all_labels) if l ==  0]
    idx_post    = [i for i, l in enumerate(all_labels) if l ==  1]

    n_non_fall  = len(idx_normal) + len(idx_post)
    max_fall    = int(n_non_fall * MAX_FALL_RATIO / (1 - MAX_FALL_RATIO))
    
    if len(idx_fall) > max_fall:
        idx_fall = random.sample(idx_fall, max_fall)
        print(f"\n⚖️  Balanceo: clase 0 reducida de {(all_labels.count(0))} → {max_fall} ventanas")

    keep = sorted(idx_normal + idx_fall + idx_post)
    all_sequences = [all_sequences[i] for i in keep]
    all_labels    = [all_labels[i]    for i in keep]
    all_meta      = [all_meta[i]      for i in keep]

X     = np.array(all_sequences, dtype=np.float32)
y_raw = np.array(all_labels,    dtype=np.int8)
meta_df = pd.DataFrame(all_meta)

np.save(DATA_DIR / "sequences.npy", X)
np.save(DATA_DIR / "labels.npy",    y_raw)
meta_df.to_csv(DATA_DIR / "meta.csv", index=False)

N_FEATURES = X.shape[2]  # se actualiza automáticamente según FEATURE_MODE

print(f"\n{'─'*55}")
print(f"✔  FEATURE_MODE : {FEATURE_MODE}  →  {N_FEATURES} features/frame")
print(f"   Shape X      : {X.shape}  (ventanas, frames, features)")
print(f"   Clase -1     : {(y_raw==-1).sum():5d} ({(y_raw==-1).mean()*100:.1f}%)")
print(f"   Clase  0     : {(y_raw== 0).sum():5d} ({(y_raw== 0).mean()*100:.1f}%)")
print(f"   Clase  1     : {(y_raw== 1).sum():5d} ({(y_raw== 1).mean()*100:.1f}%)")
# Out:
#   video (1).csv                  →    8 ventanas  (-1:  2 0:  3 1:  3)
#   video (10).csv                 →   22 ventanas  (-1: 13 0:  2 1:  7)
#   video (11).csv                 →   30 ventanas  (-1: 24 0:  2 1:  4)
#   video (12).csv                 →   10 ventanas  (-1:  3 0:  1 1:  6)
#   video (13).csv                 →    6 ventanas  (-1:  6 0:  0 1:  0)
#   video (14).csv                 →   10 ventanas  (-1:  3 0:  1 1:  6)
#   video (15).csv                 →    7 ventanas  (-1:  2 0:  2 1:  3)
#   video (16).csv                 →   10 ventanas  (-1:  2 0:  2 1:  6)
#   video (17).csv                 →    8 ventanas  (-1:  0 0:  3 1:  5)
#   video (18).csv                 →   16 ventanas  (-1:  9 0:  2 1:  5)
#   video (19).csv                 →   12 ventanas  (-1:  5 0:  3 1:  4)
#   video (2).csv                  →   18 ventanas  (-1: 12 0:  2 1:  4)
#   video (20).csv                 →   27 ventanas  (-1: 21 0:  3 1:  3)
#   video (21).csv                 →   10 ventanas  (-1:  5 0:  1 1:  4)
#   video (22).csv                 →   13 ventanas  (-1:  8 0:  0 1:  5)
#   video (23).csv                 →   18 ventanas  (-1: 13 0:  2 1:  3)
#   video (24).csv                 →   16 ventanas  (-1: 13 0:  2 1:  1)
#   video (25).csv                 →   15 ventanas  (-1:  8 0:  3 1:  4)
#   video (26).csv                 →   16 ventanas  (-1: 12 0:  2 1:  2)
#   video (27).csv                 →   15 ventanas  (-1: 10 0:  2 1:  3)
#   video (28).csv                 →   10 ventanas  (-1:  3 0:  2 1:  5)
#   video (29).csv                 →   20 ventanas  (-1: 19 0:  1 1:  0)
#   video (3).csv                  →   18 ventanas  (-1: 14 0:  3 1:  1)
#   video (30).csv                 →    8 ventanas  (-1:  4 0:  2 1:  2)
#   video (31).csv                 →   16 ventanas  (-1: 10 0:  1 1:  5)
#   video (32).csv                 →   18 ventanas  (-1: 13 0:  1 1:  4)
#   video (33).csv                 →   13 ventanas  (-1:  5 0:  2 1:  6)
#   video (34).csv                 →   26 ventanas  (-1: 21 0:  2 1:  3)
#   video (35).csv                 →   13 ventanas  (-1:  4 0:  2 1:  7)
#   video (36).csv                 →   78 ventanas  (-1: 72 0:  2 1:  4)
#   video (37).csv                 →   12 ventanas  (-1:  3 0:  2 1:  7)
#   video (38).csv                 →   21 ventanas  (-1: 15 0:  2 1:  4)
#   video (39).csv                 →    8 ventanas  (-1:  2 0:  2 1:  4)
#   video (4).csv                  →   12 ventanas  (-1:  7 0:  3 1:  2)
#   video (40).csv                 →   21 ventanas  (-1: 16 0:  3 1:  2)
#   video (41).csv                 →   23 ventanas  (-1: 17 0:  2 1:  4)
#   video (42).csv                 →    8 ventanas  (-1:  7 0:  1 1:  0)
#   video (43).csv                 →   46 ventanas  (-1: 41 0:  2 1:  3)
#   video (44).csv                 →    7 ventanas  (-1:  3 0:  2 1:  2)
#   video (45).csv                 →   12 ventanas  (-1:  6 0:  2 1:  4)
#   video (46).csv                 →   17 ventanas  (-1: 10 0:  2 1:  5)
#   video (47).csv                 →   46 ventanas  (-1: 41 0:  2 1:  3)
#   video (48).csv                 →   50 ventanas  (-1: 43 0:  2 1:  5)
#   video (49).csv                 →   31 ventanas  (-1: 28 0:  1 1:  2)
#   video (5).csv                  →   10 ventanas  (-1:  8 0:  2 1:  0)
#   video (50).csv                 →  128 ventanas  (-1:120 0:  3 1:  5)
#   video (51).csv                 →   11 ventanas  (-1:  4 0:  3 1:  4)
#   video (52).csv                 →   12 ventanas  (-1:  5 0:  2 1:  5)
#   video (53).csv                 →   22 ventanas  (-1: 16 0:  1 1:  5)
#   video (54).csv                 →   10 ventanas  (-1: 10 0:  0 1:  0)
#   video (55).csv                 →   19 ventanas  (-1: 14 0:  1 1:  4)
#   video (56).csv                 →   27 ventanas  (-1: 19 0:  2 1:  6)
#   video (57).csv                 →   35 ventanas  (-1: 29 0:  3 1:  3)
#   video (58).csv                 →   19 ventanas  (-1: 11 0:  2 1:  6)
#   video (59).csv                 →   15 ventanas  (-1:  8 0:  2 1:  5)
#   video (6).csv                  →   14 ventanas  (-1:  8 0:  2 1:  4)
#   video (60).csv                 →   16 ventanas  (-1:  8 0:  2 1:  6)
#   video (61).csv                 →   84 ventanas  (-1: 84 0:  0 1:  0)
#   video (62).csv                 →   17 ventanas  (-1: 11 0:  1 1:  5)
#   video (63).csv                 →   38 ventanas  (-1: 38 0:  0 1:  0)
#   video (64).csv                 →   12 ventanas  (-1:  8 0:  2 1:  2)
#   video (65).csv                 →   45 ventanas  (-1: 45 0:  0 1:  0)
#   video (66).csv                 →   18 ventanas  (-1: 18 0:  0 1:  0)
#   video (67).csv                 →   21 ventanas  (-1: 21 0:  0 1:  0)
#   video (68).csv                 →  102 ventanas  (-1:102 0:  0 1:  0)
#   video (69).csv                 →   83 ventanas  (-1: 83 0:  0 1:  0)
#   video (7).csv                  →    9 ventanas  (-1:  6 0:  2 1:  1)
#   video (70).csv                 →   45 ventanas  (-1: 45 0:  0 1:  0)
#   video (8).csv                  →   15 ventanas  (-1: 10 0:  1 1:  4)
#   video (9).csv                  →   12 ventanas  (-1:  5 0:  3 1:  4)
#   video (1).csv                  →   15 ventanas  (-1:  9 0:  1 1:  5)
#   video (10).csv                 →   17 ventanas  (-1:  6 0:  1 1: 10)
#   video (11).csv                 →   11 ventanas  (-1:  6 0:  1 1:  4)
#   video (12).csv                 →   12 ventanas  (-1: 10 0:  0 1:  2)
#   video (13).csv                 →   14 ventanas  (-1: 10 0:  0 1:  4)
#   video (14).csv                 →    7 ventanas  (-1:  7 0:  0 1:  0)
#   video (15).csv                 →   11 ventanas  (-1:  8 0:  0 1:  3)
#   video (16).csv                 →   15 ventanas  (-1: 12 0:  0 1:  3)
#   video (17).csv                 →   14 ventanas  (-1: 10 0:  0 1:  4)
#   video (18).csv                 →   10 ventanas  (-1:  6 0:  1 1:  3)
#   video (19).csv                 →   11 ventanas  (-1:  8 0:  0 1:  3)
#   video (2).csv                  →   14 ventanas  (-1:  7 0:  1 1:  6)
#   video (20).csv                 →   12 ventanas  (-1:  9 0:  0 1:  3)
#   video (21).csv                 →   12 ventanas  (-1:  9 0:  0 1:  3)
#   video (22).csv                 →   14 ventanas  (-1: 10 0:  0 1:  4)
#   video (23).csv                 →   14 ventanas  (-1: 10 0:  0 1:  4)
#   video (24).csv                 →   11 ventanas  (-1:  8 0:  0 1:  3)
#   video (25).csv                 →   12 ventanas  (-1: 11 0:  0 1:  1)
#   video (26).csv                 →   12 ventanas  (-1:  8 0:  0 1:  4)
#   video (27).csv                 →   14 ventanas  (-1: 11 0:  0 1:  3)
#   video (28).csv                 →   12 ventanas  (-1: 11 0:  0 1:  1)
#   video (29).csv                 →   16 ventanas  (-1: 10 0:  0 1:  6)
#   video (3).csv                  →   14 ventanas  (-1:  8 0:  0 1:  6)
#   video (30).csv                 →   11 ventanas  (-1:  8 0:  0 1:  3)
#   video (31).csv                 →   19 ventanas  (-1: 13 0:  0 1:  6)
#   video (32).csv                 →   11 ventanas  (-1:  5 0:  0 1:  6)
#   video (33).csv                 →    8 ventanas  (-1:  8 0:  0 1:  0)
#   video (34).csv                 →   13 ventanas  (-1: 10 0:  0 1:  3)
#   video (35).csv                 →    8 ventanas  (-1:  8 0:  0 1:  0)
#   video (36).csv                 →    3 ventanas  (-1:  3 0:  0 1:  0)
#   video (37).csv                 →   14 ventanas  (-1:  8 0:  1 1:  5)
#   video (38).csv                 →   11 ventanas  (-1: 11 0:  0 1:  0)
#   video (39).csv                 →   11 ventanas  (-1: 11 0:  0 1:  0)
#   video (4).csv                  →   14 ventanas  (-1:  9 0:  1 1:  4)
#   video (40).csv                 →   14 ventanas  (-1: 14 0:  0 1:  0)
#   video (41).csv                 →   14 ventanas  (-1: 14 0:  0 1:  0)
#   video (42).csv                 →    9 ventanas  (-1:  9 0:  0 1:  0)
#   video (43).csv                 →    9 ventanas  (-1:  9 0:  0 1:  0)
#   video (44).csv                 →   19 ventanas  (-1: 19 0:  0 1:  0)
#   video (45).csv                 →   12 ventanas  (-1: 12 0:  0 1:  0)
#   video (46).csv                 →   15 ventanas  (-1: 15 0:  0 1:  0)
#   video (47).csv                 →   17 ventanas  (-1: 17 0:  0 1:  0)
#   video (48).csv                 →   14 ventanas  (-1: 14 0:  0 1:  0)
#   video (49).csv                 →   19 ventanas  (-1: 19 0:  0 1:  0)
#   video (5).csv                  →    7 ventanas  (-1:  7 0:  0 1:  0)
#   video (50).csv                 →   19 ventanas  (-1: 19 0:  0 1:  0)
#   video (51).csv                 →   15 ventanas  (-1: 15 0:  0 1:  0)
#   video (52).csv                 →   12 ventanas  (-1: 12 0:  0 1:  0)
#   video (53).csv                 →   12 ventanas  (-1: 12 0:  0 1:  0)
#   video (54).csv                 →   12 ventanas  (-1: 12 0:  0 1:  0)
#   video (55).csv                 →   12 ventanas  (-1: 12 0:  0 1:  0)
#   video (56).csv                 →   22 ventanas  (-1: 22 0:  0 1:  0)
#   video (57).csv                 →   14 ventanas  (-1: 14 0:  0 1:  0)
#   video (58).csv                 →   20 ventanas  (-1: 20 0:  0 1:  0)
#   video (59).csv                 →   12 ventanas  (-1: 12 0:  0 1:  0)
#   video (6).csv                  →   11 ventanas  (-1:  7 0:  2 1:  2)
#   video (60).csv                 →   19 ventanas  (-1: 19 0:  0 1:  0)
#   video (7).csv                  →   12 ventanas  (-1:  9 0:  0 1:  3)
#   video (8).csv                  →   17 ventanas  (-1:  8 0:  0 1:  9)
#   video (9).csv                  →   18 ventanas  (-1:  9 0:  1 1:  8)
#   S_D_0002_resized_keypoints.csv →    4 ventanas  (-1:  0 0:  4 1:  0)
#   S_D_0003_anonymized_keypoints.csv →    0 ventanas  (-1:  0 0:  0 1:  0)
#   S_D_0003_keypoints.csv         →    2 ventanas  (-1:  0 0:  2 1:  0)
#   S_D_0004_resized_keypoints.csv →    6 ventanas  (-1:  0 0:  6 1:  0)
#   S_D_0005_resized_keypoints.csv →    6 ventanas  (-1:  0 0:  6 1:  0)
#   S_D_0006_keypoints.csv         →   10 ventanas  (-1:  0 0: 10 1:  0)
#   S_D_0007_keypoints.csv         →   10 ventanas  (-1:  0 0: 10 1:  0)
#   S_D_0008_keypoints.csv         →    8 ventanas  (-1:  0 0:  8 1:  0)
#   S_D_0009_keypoints.csv         →   29 ventanas  (-1:  0 0: 29 1:  0)
#   S_D_0010_keypoints.csv         →   14 ventanas  (-1:  0 0: 14 1:  0)
#   S_D_0011_keypoints.csv         →    1 ventanas  (-1:  0 0:  1 1:  0)
#   S_D_0014_keypoints.csv         →    0 ventanas  (-1:  0 0:  0 1:  0)
#   S_D_0015_keypoints.csv         →    0 ventanas  (-1:  0 0:  0 1:  0)
#   S_D_0016_resized_keypoints.csv →    3 ventanas  (-1:  0 0:  3 1:  0)
#   S_D_0017_keypoints.csv         →    2 ventanas  (-1:  0 0:  2 1:  0)
#   S_D_0018_keypoints.csv         →    0 ventanas  (-1:  0 0:  0 1:  0)
#   S_D_0019_keypoints.csv         →    0 ventanas  (-1:  0 0:  0 1:  0)
#   S_D_0020_keypoints.csv         →    0 ventanas  (-1:  0 0:  0 1:  0)
#   S_D_0021_keypoints.csv         →    1 ventanas  (-1:  0 0:  1 1:  0)
#   S_D_0022_keypoints.csv         →    0 ventanas  (-1:  0 0:  0 1:  0)
#   S_D_0023_keypoints.csv         →    0 ventanas  (-1:  0 0:  0 1:  0)
#   S_D_0024_keypoints.csv         →    2 ventanas  (-1:  0 0:  2 1:  0)
#   S_D_0028_resized_keypoints.csv →    1 ventanas  (-1:  0 0:  1 1:  0)
#   S_D_0029_keypoints.csv         →    7 ventanas  (-1:  0 0:  7 1:  0)
#   S_D_0030_resized_keypoints.csv →    4 ventanas  (-1:  0 0:  4 1:  0)
#   S_D_0031_resized_keypoints.csv →    4 ventanas  (-1:  0 0:  4 1:  0)
#   S_D_0032_resized_keypoints.csv →    2 ventanas  (-1:  0 0:  2 1:  0)
#   S_D_0033_resized_keypoints.csv →    4 ventanas  (-1:  0 0:  4 1:  0)
#   S_D_0034_resized_keypoints.csv →    6 ventanas  (-1:  0 0:  6 1:  0)
#   S_D_0035_resized_keypoints.csv →    4 ventanas  (-1:  0 0:  4 1:  0)
#   S_D_0036_resized_keypoints.csv →    4 ventanas  (-1:  0 0:  4 1:  0)
#   S_D_0037_resized_keypoints.csv →    6 ventanas  (-1:  0 0:  6 1:  0)
#   S_D_0038_resized_keypoints.csv →    6 ventanas  (-1:  0 0:  6 1:  0)
#   S_D_0039_resized_keypoints.csv →    1 ventanas  (-1:  0 0:  1 1:  0)
#   S_D_0040_resized_keypoints.csv →    3 ventanas  (-1:  0 0:  3 1:  0)
#   S_D_0041_keypoints.csv         →    6 ventanas  (-1:  0 0:  6 1:  0)
#   S_D_0042_keypoints.csv         →    3 ventanas  (-1:  0 0:  3 1:  0)
#   S_D_0043_keypoints.csv         →    6 ventanas  (-1:  0 0:  6 1:  0)
#   S_D_0044_keypoints.csv         →    6 ventanas  (-1:  0 0:  6 1:  0)
#   S_D_0045_keypoints.csv         →    2 ventanas  (-1:  0 0:  2 1:  0)
#   S_D_0046_keypoints.csv         →    4 ventanas  (-1:  0 0:  4 1:  0)
#   S_D_0047_keypoints.csv         →    2 ventanas  (-1:  0 0:  2 1:  0)
#   S_D_0049_keypoints.csv         →    4 ventanas  (-1:  0 0:  4 1:  0)
#   S_D_0050_keypoints.csv         →    2 ventanas  (-1:  0 0:  2 1:  0)
#   S_D_0051_keypoints.csv         →    4 ventanas  (-1:  0 0:  4 1:  0)
#   S_D_0052_resized_keypoints.csv →    3 ventanas  (-1:  0 0:  3 1:  0)
#   S_D_0053_keypoints.csv         →    5 ventanas  (-1:  0 0:  5 1:  0)
#   S_D_0054_keypoints.csv         →    5 ventanas  (-1:  0 0:  5 1:  0)
#   S_D_0055_keypoints.csv         →    5 ventanas  (-1:  0 0:  5 1:  0)
#   S_D_0056_keypoints.csv         →    3 ventanas  (-1:  0 0:  3 1:  0)
#   S_D_0057_keypoints.csv         →    5 ventanas  (-1:  0 0:  5 1:  0)
#   S_D_0058_keypoints.csv         →    4 ventanas  (-1:  0 0:  4 1:  0)
#   S_D_0059_keypoints.csv         →    3 ventanas  (-1:  0 0:  3 1:  0)
#   S_D_0060_keypoints.csv         →    5 ventanas  (-1:  0 0:  5 1:  0)
#   S_D_0061_keypoints.csv         →    4 ventanas  (-1:  0 0:  4 1:  0)
#   S_D_0062_keypoints.csv         →    3 ventanas  (-1:  0 0:  3 1:  0)
#   S_D_0063_keypoints.csv         →    1 ventanas  (-1:  0 0:  1 1:  0)
#   S_D_0064_resized_keypoints.csv →    4 ventanas  (-1:  0 0:  4 1:  0)
#   S_D_0065_keypoints.csv         →    4 ventanas  (-1:  0 0:  4 1:  0)
#   S_D_0066_keypoints.csv         →    2 ventanas  (-1:  0 0:  2 1:  0)
#   S_D_0067_keypoints.csv         →    4 ventanas  (-1:  0 0:  4 1:  0)
#   S_D_0068_keypoints.csv         →    6 ventanas  (-1:  0 0:  6 1:  0)
#   S_D_0069_keypoints.csv         →    5 ventanas  (-1:  0 0:  5 1:  0)
#   S_D_0070_keypoints.csv         →    6 ventanas  (-1:  0 0:  6 1:  0)
#   S_D_0076_keypoints.csv         →    5 ventanas  (-1:  0 0:  5 1:  0)
#   S_D_0077_resized_keypoints.csv →    3 ventanas  (-1:  0 0:  3 1:  0)
#   S_D_0078_resized_keypoints.csv →    5 ventanas  (-1:  0 0:  5 1:  0)
#   S_D_0079_resized_keypoints.csv →    1 ventanas  (-1:  0 0:  1 1:  0)
#   S_D_0080_resized_keypoints.csv →    5 ventanas  (-1:  0 0:  5 1:  0)
#   S_D_0081_resized_keypoints.csv →    3 ventanas  (-1:  0 0:  3 1:  0)
#   S_D_0082_resized_keypoints.csv →    1 ventanas  (-1:  0 0:  1 1:  0)
#   S_D_0083_resized_keypoints.csv →    2 ventanas  (-1:  0 0:  2 1:  0)
#   S_D_0084_resized_keypoints.csv →    0 ventanas  (-1:  0 0:  0 1:  0)
#   S_D_0085_resized_keypoints.csv →    5 ventanas  (-1:  0 0:  5 1:  0)
#   S_D_0086_resized_keypoints.csv →    3 ventanas  (-1:  0 0:  3 1:  0)
#   S_D_0087_keypoints.csv         →    5 ventanas  (-1:  0 0:  5 1:  0)
#   S_D_0088_resized_keypoints.csv →    1 ventanas  (-1:  0 0:  1 1:  0)
#   S_D_0089_resized_keypoints.csv →    2 ventanas  (-1:  0 0:  2 1:  0)
#   S_D_0090_resized_keypoints.csv →    1 ventanas  (-1:  0 0:  1 1:  0)
#   S_D_0091_resized_keypoints.csv →    3 ventanas  (-1:  0 0:  3 1:  0)
#   S_D_0092_resized_keypoints.csv →    3 ventanas  (-1:  0 0:  3 1:  0)
#   S_D_0093_resized_keypoints.csv →    4 ventanas  (-1:  0 0:  4 1:  0)
#   S_D_0094_resized_keypoints.csv →    3 ventanas  (-1:  0 0:  3 1:  0)
#   S_D_0095_resized_keypoints.csv →    5 ventanas  (-1:  0 0:  5 1:  0)
#   S_D_0096_resized_keypoints.csv →    5 ventanas  (-1:  0 0:  5 1:  0)
#   S_D_0097_resized_keypoints.csv →    3 ventanas  (-1:  0 0:  3 1:  0)
#   S_D_0098_keypoints.csv         →    4 ventanas  (-1:  0 0:  4 1:  0)
#   S_D_0099_resized_keypoints.csv →    4 ventanas  (-1:  0 0:  4 1:  0)
#   S_D_0100_resized_keypoints.csv →    6 ventanas  (-1:  0 0:  6 1:  0)
#   S_D_0101_resized_keypoints.csv →    8 ventanas  (-1:  0 0:  8 1:  0)
#   S_D_0102_resized_keypoints.csv →    8 ventanas  (-1:  0 0:  8 1:  0)
#   S_D_0103_resized_keypoints.csv →    6 ventanas  (-1:  0 0:  6 1:  0)
#   S_D_0104_resized_keypoints.csv →    6 ventanas  (-1:  0 0:  6 1:  0)
#   S_D_0105_resized_keypoints.csv →    8 ventanas  (-1:  0 0:  8 1:  0)
#   S_D_0106_resized_keypoints.csv →    6 ventanas  (-1:  0 0:  6 1:  0)
#   S_D_0107_resized_keypoints.csv →    6 ventanas  (-1:  0 0:  6 1:  0)
#   S_D_0108_resized_keypoints.csv →    8 ventanas  (-1:  0 0:  8 1:  0)
#   S_D_0109_keypoints.csv         →    5 ventanas  (-1:  0 0:  5 1:  0)
#   S_D_0110_keypoints.csv         →    9 ventanas  (-1:  0 0:  9 1:  0)
#   S_D_0111_keypoints.csv         →    5 ventanas  (-1:  0 0:  5 1:  0)
#   S_D_0112_keypoints.csv         →    1 ventanas  (-1:  0 0:  1 1:  0)
#   S_D_0113_keypoints.csv         →    8 ventanas  (-1:  0 0:  8 1:  0)
#   S_D_0114_keypoints.csv         →    6 ventanas  (-1:  0 0:  6 1:  0)
#   S_D_0115_keypoints.csv         →    7 ventanas  (-1:  0 0:  7 1:  0)
#   S_D_0116_keypoints.csv         →    1 ventanas  (-1:  0 0:  1 1:  0)
#   S_D_0117_keypoints.csv         →    2 ventanas  (-1:  0 0:  2 1:  0)
#   S_D_0118_keypoints.csv         →    3 ventanas  (-1:  0 0:  3 1:  0)
#   S_D_0119_keypoints.csv         →    2 ventanas  (-1:  0 0:  2 1:  0)
#   S_D_0120_resized_keypoints.csv →    4 ventanas  (-1:  0 0:  4 1:  0)
#   S_D_0121_keypoints.csv         →    3 ventanas  (-1:  0 0:  3 1:  0)
#   S_D_0122_keypoints.csv         →    5 ventanas  (-1:  0 0:  5 1:  0)
#   S_D_0123_keypoints.csv         →    8 ventanas  (-1:  0 0:  8 1:  0)
#   S_D_0124_keypoints.csv         →    8 ventanas  (-1:  0 0:  8 1:  0)
#   S_D_0125_keypoints.csv         →    8 ventanas  (-1:  0 0:  8 1:  0)
#   S_D_0126_keypoints.csv         →    6 ventanas  (-1:  0 0:  6 1:  0)
#   S_D_0127_keypoints.csv         →    6 ventanas  (-1:  0 0:  6 1:  0)
#   S_D_0128_keypoints.csv         →    5 ventanas  (-1:  0 0:  5 1:  0)
#   S_D_0129_keypoints.csv         →    4 ventanas  (-1:  0 0:  4 1:  0)
#   S_D_0130_keypoints.csv         →    6 ventanas  (-1:  0 0:  6 1:  0)
#   S_D_0131_keypoints.csv         →    6 ventanas  (-1:  0 0:  6 1:  0)
#   S_D_0132_keypoints.csv         →    4 ventanas  (-1:  0 0:  4 1:  0)
#   S_D_0133_keypoints.csv         →    5 ventanas  (-1:  0 0:  5 1:  0)
#   S_D_0134_resized_keypoints.csv →    4 ventanas  (-1:  0 0:  4 1:  0)
#   S_D_0135_resized_keypoints.csv →    8 ventanas  (-1:  0 0:  8 1:  0)
#   S_D_0136_resized_keypoints.csv →    6 ventanas  (-1:  0 0:  6 1:  0)
#   S_D_0137_resized_keypoints.csv →    6 ventanas  (-1:  0 0:  6 1:  0)
#   S_D_0138_resized_keypoints.csv →    8 ventanas  (-1:  0 0:  8 1:  0)
#   S_D_0139_resized_keypoints.csv →    2 ventanas  (-1:  0 0:  2 1:  0)
#   S_D_0140_resized_keypoints.csv →    3 ventanas  (-1:  0 0:  3 1:  0)
#   S_D_0141_resized_keypoints.csv →    3 ventanas  (-1:  0 0:  3 1:  0)
#   S_D_0142_resized_keypoints.csv →    4 ventanas  (-1:  0 0:  4 1:  0)
#   S_D_0143_resized_keypoints.csv →    5 ventanas  (-1:  0 0:  5 1:  0)
#   S_D_0144_keypoints.csv         →    4 ventanas  (-1:  0 0:  4 1:  0)
#   S_D_0145_keypoints.csv         →    4 ventanas  (-1:  0 0:  4 1:  0)
#   S_D_0147_resized_keypoints.csv →    7 ventanas  (-1:  0 0:  7 1:  0)
#   S_D_0148_resized_keypoints.csv →    6 ventanas  (-1:  0 0:  6 1:  0)
#   S_D_0149_resized_keypoints.csv →    5 ventanas  (-1:  0 0:  5 1:  0)
#   S_D_0150_resized_keypoints.csv →    4 ventanas  (-1:  0 0:  4 1:  0)
#   S_D_0151_resized_keypoints.csv →    5 ventanas  (-1:  0 0:  5 1:  0)
#   S_D_0152_resized_keypoints.csv →    7 ventanas  (-1:  0 0:  7 1:  0)
#   S_D_0153_resized_keypoints.csv →    6 ventanas  (-1:  0 0:  6 1:  0)
#   S_D_0154_resized_keypoints.csv →    8 ventanas  (-1:  0 0:  8 1:  0)
#   S_D_0155_keypoints.csv         →    4 ventanas  (-1:  0 0:  4 1:  0)
#   S_D_0156_keypoints.csv         →    5 ventanas  (-1:  0 0:  5 1:  0)
#   S_D_0157_keypoints.csv         →    5 ventanas  (-1:  0 0:  5 1:  0)
#   S_D_0158_keypoints.csv         →    2 ventanas  (-1:  0 0:  2 1:  0)
#   S_D_0159_keypoints.csv         →    1 ventanas  (-1:  0 0:  1 1:  0)
#   S_D_0160_keypoints.csv         →    2 ventanas  (-1:  0 0:  2 1:  0)
#   S_D_0161_keypoints.csv         →    2 ventanas  (-1:  0 0:  2 1:  0)
#   S_D_0162_resized_keypoints.csv →    8 ventanas  (-1:  0 0:  8 1:  0)
#   S_D_0163_resized_keypoints.csv →    6 ventanas  (-1:  0 0:  6 1:  0)
#   S_D_0164_resized_keypoints.csv →    8 ventanas  (-1:  0 0:  8 1:  0)
#   S_D_0165_resized_keypoints.csv →    6 ventanas  (-1:  0 0:  6 1:  0)
#   S_D_0166_keypoints.csv         →    7 ventanas  (-1:  0 0:  7 1:  0)
#   S_D_0167_resized_keypoints.csv →    8 ventanas  (-1:  0 0:  8 1:  0)
#   S_D_0168_keypoints.csv         →    4 ventanas  (-1:  0 0:  4 1:  0)
#   S_D_0169_keypoints.csv         →    4 ventanas  (-1:  0 0:  4 1:  0)
#   S_D_0170_keypoints.csv         →    4 ventanas  (-1:  0 0:  4 1:  0)
#   S_D_0171_keypoints.csv         →    6 ventanas  (-1:  0 0:  6 1:  0)
#   S_D_0172_keypoints.csv         →    6 ventanas  (-1:  0 0:  6 1:  0)
#   S_D_0173_keypoints.csv         →    6 ventanas  (-1:  0 0:  6 1:  0)
#   S_D_0174_keypoints.csv         →    3 ventanas  (-1:  0 0:  3 1:  0)
#   S_D_0175_resized_keypoints.csv →    4 ventanas  (-1:  0 0:  4 1:  0)
#   S_D_0176_keypoints.csv         →    6 ventanas  (-1:  0 0:  6 1:  0)
#   S_D_0177_keypoints.csv         →    4 ventanas  (-1:  0 0:  4 1:  0)
#   S_D_0178_keypoints.csv         →    3 ventanas  (-1:  0 0:  3 1:  0)
#   S_D_0179_keypoints.csv         →    3 ventanas  (-1:  0 0:  3 1:  0)
#   S_D_0180_keypoints.csv         →    1 ventanas  (-1:  0 0:  1 1:  0)
#   S_D_0181_keypoints.csv         →    1 ventanas  (-1:  0 0:  1 1:  0)
#   S_D_0182_keypoints.csv         →    4 ventanas  (-1:  0 0:  4 1:  0)
#   S_D_0183_keypoints.csv         →    4 ventanas  (-1:  0 0:  4 1:  0)
#   S_D_0184_keypoints.csv         →    5 ventanas  (-1:  0 0:  5 1:  0)
#   S_D_0185_keypoints.csv         →    5 ventanas  (-1:  0 0:  5 1:  0)
#   S_D_0186_keypoints.csv         →    6 ventanas  (-1:  0 0:  6 1:  0)
#   S_D_0187_resized_keypoints.csv →    4 ventanas  (-1:  0 0:  4 1:  0)
#   S_D_0188_keypoints.csv         →    6 ventanas  (-1:  0 0:  6 1:  0)
#   S_D_0189_keypoints.csv         →    6 ventanas  (-1:  0 0:  6 1:  0)
#   S_D_0190_keypoints.csv         →    5 ventanas  (-1:  0 0:  5 1:  0)
#   S_D_0191_keypoints.csv         →    5 ventanas  (-1:  0 0:  5 1:  0)
#   S_D_0192_keypoints.csv         →    3 ventanas  (-1:  0 0:  3 1:  0)
#   S_D_0193_keypoints.csv         →    3 ventanas  (-1:  0 0:  3 1:  0)
#   S_D_0194_keypoints.csv         →    6 ventanas  (-1:  0 0:  6 1:  0)
#   S_D_0195_keypoints.csv         →    4 ventanas  (-1:  0 0:  4 1:  0)
#   S_D_0196_keypoints.csv         →    2 ventanas  (-1:  0 0:  2 1:  0)
#   S_D_0197_keypoints.csv         →    2 ventanas  (-1:  0 0:  2 1:  0)
#   S_D_0198_keypoints.csv         →    8 ventanas  (-1:  0 0:  8 1:  0)
#   S_D_0199_resized_keypoints.csv →    6 ventanas  (-1:  0 0:  6 1:  0)
#   S_D_0200_keypoints.csv         →    6 ventanas  (-1:  0 0:  6 1:  0)
#   S_D_0201_keypoints.csv         →    6 ventanas  (-1:  0 0:  6 1:  0)
#   S_D_0202_keypoints.csv         →    8 ventanas  (-1:  0 0:  8 1:  0)
#   S_D_0203_keypoints.csv         →    8 ventanas  (-1:  0 0:  8 1:  0)
#   S_D_0205_keypoints.csv         →    5 ventanas  (-1:  0 0:  5 1:  0)
#   S_D_0206_keypoints.csv         →    3 ventanas  (-1:  0 0:  3 1:  0)
#   S_D_0207_keypoints.csv         →    6 ventanas  (-1:  0 0:  6 1:  0)
#   S_D_0208_keypoints.csv         →    6 ventanas  (-1:  0 0:  6 1:  0)
#   S_D_0209_keypoints.csv         →    7 ventanas  (-1:  0 0:  7 1:  0)
#   S_D_0210_keypoints.csv         →    4 ventanas  (-1:  0 0:  4 1:  0)
#   S_D_0211_resized_keypoints.csv →    4 ventanas  (-1:  0 0:  4 1:  0)
#   S_D_0212_keypoints.csv         →    6 ventanas  (-1:  0 0:  6 1:  0)
#   S_D_0213_keypoints.csv         →    5 ventanas  (-1:  0 0:  5 1:  0)
#   S_D_0214_keypoints.csv         →    5 ventanas  (-1:  0 0:  5 1:  0)
#   S_D_0215_keypoints.csv         →    6 ventanas  (-1:  0 0:  6 1:  0)
#   S_D_0216_keypoints.csv         →    6 ventanas  (-1:  0 0:  6 1:  0)
#   S_D_0217_keypoints.csv         →    0 ventanas  (-1:  0 0:  0 1:  0)
#   S_D_0218_keypoints.csv         →    5 ventanas  (-1:  0 0:  5 1:  0)
#   S_D_0219_keypoints.csv         →   35 ventanas  (-1:  0 0: 35 1:  0)
#   S_D_0220_keypoints.csv         →    6 ventanas  (-1:  0 0:  6 1:  0)
#   S_D_0221_keypoints.csv         →    6 ventanas  (-1:  0 0:  6 1:  0)
#   S_D_0222_keypoints.csv         →    6 ventanas  (-1:  0 0:  6 1:  0)
#   S_D_0223_resized_keypoints.csv →    6 ventanas  (-1:  0 0:  6 1:  0)
#   S_D_0224_keypoints.csv         →    4 ventanas  (-1:  0 0:  4 1:  0)
#   S_D_0225_keypoints.csv         →    5 ventanas  (-1:  0 0:  5 1:  0)
#   S_D_0226_keypoints.csv         →    8 ventanas  (-1:  0 0:  8 1:  0)
#   S_D_0227_keypoints.csv         →    6 ventanas  (-1:  0 0:  6 1:  0)
#   S_D_0229_resized_keypoints.csv →    6 ventanas  (-1:  0 0:  6 1:  0)
#   S_D_0230_resized_keypoints.csv →    6 ventanas  (-1:  0 0:  6 1:  0)
#   S_D_0231_resized_keypoints.csv →    8 ventanas  (-1:  0 0:  8 1:  0)
#   S_D_0233_resized_keypoints.csv →    6 ventanas  (-1:  0 0:  6 1:  0)
#   S_D_0234_resized_keypoints.csv →    8 ventanas  (-1:  0 0:  8 1:  0)
#   S_D_0235_resized_keypoints.csv →    6 ventanas  (-1:  0 0:  6 1:  0)
#   S_D_0236_keypoints.csv         →    6 ventanas  (-1:  0 0:  6 1:  0)
#   S_D_0237_resized_keypoints.csv →    5 ventanas  (-1:  0 0:  5 1:  0)
#   S_D_0238_resized_keypoints.csv →    4 ventanas  (-1:  0 0:  4 1:  0)
#   S_D_0239_resized_keypoints.csv →    6 ventanas  (-1:  0 0:  6 1:  0)
#   S_D_0240_resized_keypoints.csv →    6 ventanas  (-1:  0 0:  6 1:  0)
#   S_D_0241_resized_keypoints.csv →    8 ventanas  (-1:  0 0:  8 1:  0)
#   S_D_0242_keypoints.csv         →    6 ventanas  (-1:  0 0:  6 1:  0)
#   S_D_0243_keypoints.csv         →    8 ventanas  (-1:  0 0:  8 1:  0)
#   S_D_0244_keypoints.csv         →    8 ventanas  (-1:  0 0:  8 1:  0)
#   S_D_0245_keypoints.csv         →    8 ventanas  (-1:  0 0:  8 1:  0)
#   S_D_0246_keypoints.csv         →    8 ventanas  (-1:  0 0:  8 1:  0)
#   S_D_0247_resized_keypoints.csv →    4 ventanas  (-1:  0 0:  4 1:  0)
#   S_D_0248_keypoints.csv         →    6 ventanas  (-1:  0 0:  6 1:  0)
#   S_D_0249_keypoints.csv         →    6 ventanas  (-1:  0 0:  6 1:  0)
#   S_D_0250_keypoints.csv         →   10 ventanas  (-1:  0 0: 10 1:  0)
#   S_D_0251_keypoints.csv         →    8 ventanas  (-1:  0 0:  8 1:  0)
#   S_D_0252_keypoints.csv         →    8 ventanas  (-1:  0 0:  8 1:  0)
#   S_D_0253_keypoints.csv         →    6 ventanas  (-1:  0 0:  6 1:  0)
#   S_D_0254_keypoints.csv         →    8 ventanas  (-1:  0 0:  8 1:  0)
#   S_D_0255_keypoints.csv         →    5 ventanas  (-1:  0 0:  5 1:  0)
#   S_D_0256_keypoints.csv         →    3 ventanas  (-1:  0 0:  3 1:  0)
#   S_D_0257_keypoints.csv         →   10 ventanas  (-1:  0 0: 10 1:  0)
#   S_D_0258_keypoints.csv         →    2 ventanas  (-1:  0 0:  2 1:  0)
#
# ───────────────────────────────────────────────────────
# ✔  FEATURE_MODE : coco_xy_vel  →  68 features/frame
#    Shape X      : (3659, 40, 68)  (ventanas, frames, features)
#    Clase -1     :  1960 (53.6%)
#    Clase  0     :  1334 (36.5%)
#    Clase  1     :   365 (10.0%)

# %% [markdown]
# ## 1. Imports y configuración

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from pathlib import Path
from collections import Counter

import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader, WeightedRandomSampler
from sklearn.model_selection import train_test_split
from sklearn.metrics import (
    classification_report, confusion_matrix,
    ConfusionMatrixDisplay, f1_score
)

# ── Configuración ──────────────────────────────────────────────
DATA_DIR    = Path("./lstm_data")   # carpeta con sequences.npy y labels.npy                
N_FEATURES  = X.shape[2]                  # 33 landmarks × (x,y,z,vis)
N_CLASSES   = 3                     # -1, 0, 1
LABEL_MAP   = {-1: 0, 0: 1, 1: 2}  # remapeo para CrossEntropy (necesita 0,1,2)
LABEL_NAMES = ["Normal (-1)", "Caída (0)", "Post-caída (1)"]

# Hiperparámetros
HIDDEN_SIZE  = 128
NUM_LAYERS   = 2
DROPOUT      = 0.3
BATCH_SIZE   = 32
EPOCHS       = 50
LR           = 1e-3
VAL_SIZE     = 0.2
TEST_SIZE    = 0.1
SEED         = 42
PATIENCE_ES  = 10    # épocas sin mejora antes de parar

DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Dispositivo: {DEVICE}")

torch.manual_seed(SEED)
np.random.seed(SEED)
# Out:
# Dispositivo: cuda

# %% [markdown]
# ## 2. Carga y exploración de datos

# %%
X = np.load(DATA_DIR / "sequences.npy")   # (N, 20, 132)
y_raw = np.load(DATA_DIR / "labels.npy")  # (N,) con valores -1, 0, 1
meta = pd.read_csv(DATA_DIR / "meta.csv")

# Remapear etiquetas a 0,1,2 para PyTorch
y = np.array([LABEL_MAP[l] for l in y_raw], dtype=np.int64)

print(f"Shape X : {X.shape}")
print(f"Shape y : {y.shape}")
print(f"\nDistribución de clases:")
for label, name in zip([0,1,2], LABEL_NAMES):
    n = (y == label).sum()
    print(f"  {name:20s}: {n:5d} ({n/len(y)*100:.1f}%)")
# Out:
# Shape X : (3659, 40, 68)
# Shape y : (3659,)
#
# Distribución de clases:
#   Normal (-1)         :  1960 (53.6%)
#   Caída (0)           :  1334 (36.5%)
#   Post-caída (1)      :   365 (10.0%)

# %%
# Visualización del balance de clases
fig, axes = plt.subplots(1, 2, figsize=(12, 4))

counts = [int((y == i).sum()) for i in range(3)]
colors = ["#4CAF50", "#F44336", "#FF9800"]

axes[0].bar(LABEL_NAMES, counts, color=colors)
axes[0].set_title("Balance de clases")
axes[0].set_ylabel("Número de ventanas")
for i, v in enumerate(counts):
    axes[0].text(i, v + 10, str(v), ha="center", fontweight="bold")

axes[1].pie(counts, labels=LABEL_NAMES, colors=colors, autopct="%1.1f%%", startangle=90)
axes[1].set_title("Proporción de clases")

plt.tight_layout()
plt.show()

# %%
# Distribución de ventanas por video
meta["label_name"] = meta["label"].map({-1: "Normal", 0: "Caída", 1: "Post-caída"})
video_summary = meta.groupby("video")["label"].value_counts().unstack(fill_value=0)
print("Ventanas por video:")
print(video_summary.to_string())
# Out:
# Ventanas por video:
# label                                  -1   0   1
# video
# Coffee_room/video (1)                   2   3   3
# Coffee_room/video (10)                 13   2   7
# Coffee_room/video (11)                 24   2   4
# Coffee_room/video (12)                  3   1   6
# Coffee_room/video (13)                  6   0   0
# Coffee_room/video (14)                  3   1   6
# Coffee_room/video (15)                  2   2   3
# Coffee_room/video (16)                  2   2   6
# Coffee_room/video (17)                  0   3   5
# Coffee_room/video (18)                  9   2   5
# Coffee_room/video (19)                  5   3   4
# Coffee_room/video (2)                  12   2   4
# Coffee_room/video (20)                 21   3   3
# Coffee_room/video (21)                  5   1   4
# Coffee_room/video (22)                  8   0   5
# Coffee_room/video (23)                 13   2   3
# Coffee_room/video (24)                 13   2   1
# Coffee_room/video (25)                  8   3   4
# Coffee_room/video (26)                 12   2   2
# Coffee_room/video (27)                 10   2   3
# Coffee_room/video (28)                  3   2   5
# Coffee_room/video (29)                 19   1   0
# Coffee_room/video (3)                  14   3   1
# Coffee_room/video (30)                  4   2   2
# Coffee_room/video (31)                 10   1   5
# Coffee_room/video (32)                 13   1   4
# Coffee_room/video (33)                  5   2   6
# Coffee_room/video (34)                 21   2   3
# Coffee_room/video (35)                  4   2   7
# Coffee_room/video (36)                 72   2   4
# Coffee_room/video (37)                  3   2   7
# Coffee_room/video (38)                 15   2   4
# Coffee_room/video (39)                  2   2   4
# Coffee_room/video (4)                   7   3   2
# Coffee_room/video (40)                 16   3   2
# Coffee_room/video (41)                 17   2   4
# Coffee_room/video (42)                  7   1   0
# Coffee_room/video (43)                 41   2   3
# Coffee_room/video (44)                  3   2   2
# Coffee_room/video (45)                  6   2   4
# Coffee_room/video (46)                 10   2   5
# Coffee_room/video (47)                 41   2   3
# Coffee_room/video (48)                 43   2   5
# Coffee_room/video (49)                 28   1   2
# Coffee_room/video (5)                   8   2   0
# Coffee_room/video (50)                120   3   5
# Coffee_room/video (51)                  4   3   4
# Coffee_room/video (52)                  5   2   5
# Coffee_room/video (53)                 16   1   5
# Coffee_room/video (54)                 10   0   0
# Coffee_room/video (55)                 14   1   4
# Coffee_room/video (56)                 19   2   6
# Coffee_room/video (57)                 29   3   3
# Coffee_room/video (58)                 11   2   6
# Coffee_room/video (59)                  8   2   5
# Coffee_room/video (6)                   8   2   4
# Coffee_room/video (60)                  8   2   6
# Coffee_room/video (61)                 84   0   0
# Coffee_room/video (62)                 11   1   5
# Coffee_room/video (63)                 38   0   0
# Coffee_room/video (64)                  8   2   2
# Coffee_room/video (65)                 45   0   0
# Coffee_room/video (66)                 18   0   0
# Coffee_room/video (67)                 21   0   0
# Coffee_room/video (68)                102   0   0
# Coffee_room/video (69)                 83   0   0
# Coffee_room/video (7)                   6   2   1
# Coffee_room/video (70)                 45   0   0
# Coffee_room/video (8)                  10   1   4
# Coffee_room/video (9)                   5   3   4
# Home_room/video (1)                     9   1   5
# Home_room/video (10)                    6   1  10
# Home_room/video (11)                    6   1   4
# Home_room/video (12)                   10   0   2
# Home_room/video (13)                   10   0   4
# Home_room/video (14)                    7   0   0
# Home_room/video (15)                    8   0   3
# Home_room/video (16)                   12   0   3
# Home_room/video (17)                   10   0   4
# Home_room/video (18)                    6   1   3
# Home_room/video (19)                    8   0   3
# Home_room/video (2)                     7   1   6
# Home_room/video (20)                    9   0   3
# Home_room/video (21)                    9   0   3
# Home_room/video (22)                   10   0   4
# Home_room/video (23)                   10   0   4
# Home_room/video (24)                    8   0   3
# Home_room/video (25)                   11   0   1
# Home_room/video (26)                    8   0   4
# Home_room/video (27)                   11   0   3
# Home_room/video (28)                   11   0   1
# Home_room/video (29)                   10   0   6
# Home_room/video (3)                     8   0   6
# Home_room/video (30)                    8   0   3
# Home_room/video (31)                   13   0   6
# Home_room/video (32)                    5   0   6
# Home_room/video (33)                    8   0   0
# Home_room/video (34)                   10   0   3
# Home_room/video (35)                    8   0   0
# Home_room/video (36)                    3   0   0
# Home_room/video (37)                    8   1   5
# Home_room/video (38)                   11   0   0
# Home_room/video (39)                   11   0   0
# Home_room/video (4)                     9   1   4
# Home_room/video (40)                   14   0   0
# Home_room/video (41)                   14   0   0
# Home_room/video (42)                    9   0   0
# Home_room/video (43)                    9   0   0
# Home_room/video (44)                   19   0   0
# Home_room/video (45)                   12   0   0
# Home_room/video (46)                   15   0   0
# Home_room/video (47)                   17   0   0
# Home_room/video (48)                   14   0   0
# Home_room/video (49)                   19   0   0
# Home_room/video (5)                     7   0   0
# Home_room/video (50)                   19   0   0
# Home_room/video (51)                   15   0   0
# Home_room/video (52)                   12   0   0
# Home_room/video (53)                   12   0   0
# Home_room/video (54)                   12   0   0
# Home_room/video (55)                   12   0   0
# Home_room/video (56)                   22   0   0
# Home_room/video (57)                   14   0   0
# Home_room/video (58)                   20   0   0
# Home_room/video (59)                   12   0   0
# Home_room/video (6)                     7   2   2
# Home_room/video (60)                   19   0   0
# Home_room/video (7)                     9   0   3
# Home_room/video (8)                     8   0   9
# Home_room/video (9)                     9   1   8
# f_raw_s_1/S_D_0002_resized_keypoints    0   4   0
# f_raw_s_1/S_D_0003_keypoints            0   2   0
# f_raw_s_1/S_D_0004_resized_keypoints    0   6   0
# f_raw_s_1/S_D_0005_resized_keypoints    0   6   0
# f_raw_s_1/S_D_0006_keypoints            0  10   0
# f_raw_s_1/S_D_0007_keypoints            0  10   0
# f_raw_s_1/S_D_0008_keypoints            0   8   0
# f_raw_s_1/S_D_0009_keypoints            0  29   0
# f_raw_s_1/S_D_0010_keypoints            0  14   0
# f_raw_s_1/S_D_0011_keypoints            0   1   0
# f_raw_s_1/S_D_0016_resized_keypoints    0   3   0
# f_raw_s_1/S_D_0017_keypoints            0   2   0
# f_raw_s_1/S_D_0021_keypoints            0   1   0
# f_raw_s_1/S_D_0024_keypoints            0   2   0
# f_raw_s_1/S_D_0028_resized_keypoints    0   1   0
# f_raw_s_1/S_D_0029_keypoints            0   7   0
# f_raw_s_1/S_D_0030_resized_keypoints    0   4   0
# f_raw_s_1/S_D_0031_resized_keypoints    0   4   0
# f_raw_s_1/S_D_0032_resized_keypoints    0   2   0
# f_raw_s_1/S_D_0033_resized_keypoints    0   4   0
# f_raw_s_1/S_D_0034_resized_keypoints    0   6   0
# f_raw_s_1/S_D_0035_resized_keypoints    0   4   0
# f_raw_s_1/S_D_0036_resized_keypoints    0   4   0
# f_raw_s_1/S_D_0037_resized_keypoints    0   6   0
# f_raw_s_1/S_D_0038_resized_keypoints    0   6   0
# f_raw_s_1/S_D_0039_resized_keypoints    0   1   0
# f_raw_s_1/S_D_0040_resized_keypoints    0   3   0
# f_raw_s_1/S_D_0041_keypoints            0   6   0
# f_raw_s_1/S_D_0042_keypoints            0   3   0
# f_raw_s_1/S_D_0043_keypoints            0   6   0
# f_raw_s_1/S_D_0044_keypoints            0   6   0
# f_raw_s_1/S_D_0045_keypoints            0   2   0
# f_raw_s_1/S_D_0046_keypoints            0   4   0
# f_raw_s_1/S_D_0047_keypoints            0   2   0
# f_raw_s_1/S_D_0049_keypoints            0   4   0
# f_raw_s_1/S_D_0050_keypoints            0   2   0
# f_raw_s_1/S_D_0051_keypoints            0   4   0
# f_raw_s_1/S_D_0052_resized_keypoints    0   3   0
# f_raw_s_1/S_D_0053_keypoints            0   5   0
# f_raw_s_1/S_D_0054_keypoints            0   5   0
# f_raw_s_1/S_D_0055_keypoints            0   5   0
# f_raw_s_1/S_D_0056_keypoints            0   3   0
# f_raw_s_1/S_D_0057_keypoints            0   5   0
# f_raw_s_1/S_D_0058_keypoints            0   4   0
# f_raw_s_1/S_D_0059_keypoints            0   3   0
# f_raw_s_1/S_D_0060_keypoints            0   5   0
# f_raw_s_1/S_D_0061_keypoints            0   4   0
# f_raw_s_1/S_D_0062_keypoints            0   3   0
# f_raw_s_1/S_D_0063_keypoints            0   1   0
# f_raw_s_1/S_D_0064_resized_keypoints    0   4   0
# f_raw_s_1/S_D_0065_keypoints            0   4   0
# f_raw_s_1/S_D_0066_keypoints            0   2   0
# f_raw_s_1/S_D_0067_keypoints            0   4   0
# f_raw_s_1/S_D_0068_keypoints            0   6   0
# f_raw_s_1/S_D_0069_keypoints            0   5   0
# f_raw_s_1/S_D_0070_keypoints            0   6   0
# f_raw_s_1/S_D_0076_keypoints            0   5   0
# f_raw_s_1/S_D_0077_resized_keypoints    0   3   0
# f_raw_s_1/S_D_0078_resized_keypoints    0   5   0
# f_raw_s_1/S_D_0079_resized_keypoints    0   1   0
# f_raw_s_1/S_D_0080_resized_keypoints    0   5   0
# f_raw_s_1/S_D_0081_resized_keypoints    0   3   0
# f_raw_s_1/S_D_0082_resized_keypoints    0   1   0
# f_raw_s_1/S_D_0083_resized_keypoints    0   2   0
# f_raw_s_1/S_D_0085_resized_keypoints    0   5   0
# f_raw_s_1/S_D_0086_resized_keypoints    0   3   0
# f_raw_s_1/S_D_0087_keypoints            0   5   0
# f_raw_s_1/S_D_0088_resized_keypoints    0   1   0
# f_raw_s_1/S_D_0089_resized_keypoints    0   2   0
# f_raw_s_1/S_D_0090_resized_keypoints    0   1   0
# f_raw_s_1/S_D_0091_resized_keypoints    0   3   0
# f_raw_s_1/S_D_0092_resized_keypoints    0   3   0
# f_raw_s_1/S_D_0093_resized_keypoints    0   4   0
# f_raw_s_1/S_D_0094_resized_keypoints    0   3   0
# f_raw_s_1/S_D_0095_resized_keypoints    0   5   0
# f_raw_s_1/S_D_0096_resized_keypoints    0   5   0
# f_raw_s_1/S_D_0097_resized_keypoints    0   3   0
# f_raw_s_1/S_D_0098_keypoints            0   4   0
# f_raw_s_1/S_D_0099_resized_keypoints    0   4   0
# f_raw_s_1/S_D_0100_resized_keypoints    0   6   0
# f_raw_s_1/S_D_0101_resized_keypoints    0   8   0
# f_raw_s_1/S_D_0102_resized_keypoints    0   8   0
# f_raw_s_1/S_D_0103_resized_keypoints    0   6   0
# f_raw_s_1/S_D_0104_resized_keypoints    0   6   0
# f_raw_s_1/S_D_0105_resized_keypoints    0   8   0
# f_raw_s_1/S_D_0106_resized_keypoints    0   6   0
# f_raw_s_1/S_D_0107_resized_keypoints    0   6   0
# f_raw_s_1/S_D_0108_resized_keypoints    0   8   0
# f_raw_s_1/S_D_0109_keypoints            0   5   0
# f_raw_s_1/S_D_0110_keypoints            0   9   0
# f_raw_s_1/S_D_0111_keypoints            0   5   0
# f_raw_s_1/S_D_0112_keypoints            0   1   0
# f_raw_s_1/S_D_0113_keypoints            0   8   0
# f_raw_s_1/S_D_0114_keypoints            0   6   0
# f_raw_s_1/S_D_0115_keypoints            0   7   0
# f_raw_s_1/S_D_0116_keypoints            0   1   0
# f_raw_s_1/S_D_0117_keypoints            0   2   0
# f_raw_s_1/S_D_0118_keypoints            0   3   0
# f_raw_s_1/S_D_0119_keypoints            0   2   0
# f_raw_s_1/S_D_0120_resized_keypoints    0   4   0
# f_raw_s_1/S_D_0121_keypoints            0   3   0
# f_raw_s_1/S_D_0122_keypoints            0   5   0
# f_raw_s_1/S_D_0123_keypoints            0   8   0
# f_raw_s_1/S_D_0124_keypoints            0   8   0
# f_raw_s_1/S_D_0125_keypoints            0   8   0
# f_raw_s_1/S_D_0126_keypoints            0   6   0
# f_raw_s_1/S_D_0127_keypoints            0   6   0
# f_raw_s_1/S_D_0128_keypoints            0   5   0
# f_raw_s_1/S_D_0129_keypoints            0   4   0
# f_raw_s_1/S_D_0130_keypoints            0   6   0
# f_raw_s_1/S_D_0131_keypoints            0   6   0
# f_raw_s_1/S_D_0132_keypoints            0   4   0
# f_raw_s_1/S_D_0133_keypoints            0   5   0
# f_raw_s_1/S_D_0134_resized_keypoints    0   4   0
# f_raw_s_1/S_D_0135_resized_keypoints    0   8   0
# f_raw_s_1/S_D_0136_resized_keypoints    0   6   0
# f_raw_s_1/S_D_0137_resized_keypoints    0   6   0
# f_raw_s_1/S_D_0138_resized_keypoints    0   8   0
# f_raw_s_1/S_D_0139_resized_keypoints    0   2   0
# f_raw_s_1/S_D_0140_resized_keypoints    0   3   0
# f_raw_s_1/S_D_0141_resized_keypoints    0   3   0
# f_raw_s_1/S_D_0142_resized_keypoints    0   4   0
# f_raw_s_1/S_D_0143_resized_keypoints    0   5   0
# f_raw_s_1/S_D_0144_keypoints            0   4   0
# f_raw_s_1/S_D_0145_keypoints            0   4   0
# f_raw_s_1/S_D_0147_resized_keypoints    0   7   0
# f_raw_s_1/S_D_0148_resized_keypoints    0   6   0
# f_raw_s_1/S_D_0149_resized_keypoints    0   5   0
# f_raw_s_1/S_D_0150_resized_keypoints    0   4   0
# f_raw_s_1/S_D_0151_resized_keypoints    0   5   0
# f_raw_s_1/S_D_0152_resized_keypoints    0   7   0
# f_raw_s_1/S_D_0153_resized_keypoints    0   6   0
# f_raw_s_1/S_D_0154_resized_keypoints    0   8   0
# f_raw_s_1/S_D_0155_keypoints            0   4   0
# f_raw_s_1/S_D_0156_keypoints            0   5   0
# f_raw_s_1/S_D_0157_keypoints            0   5   0
# f_raw_s_1/S_D_0158_keypoints            0   2   0
# f_raw_s_1/S_D_0159_keypoints            0   1   0
# f_raw_s_1/S_D_0160_keypoints            0   2   0
# f_raw_s_1/S_D_0161_keypoints            0   2   0
# f_raw_s_1/S_D_0162_resized_keypoints    0   8   0
# f_raw_s_1/S_D_0163_resized_keypoints    0   6   0
# f_raw_s_1/S_D_0164_resized_keypoints    0   8   0
# f_raw_s_1/S_D_0165_resized_keypoints    0   6   0
# f_raw_s_1/S_D_0166_keypoints            0   7   0
# f_raw_s_1/S_D_0167_resized_keypoints    0   8   0
# f_raw_s_1/S_D_0168_keypoints            0   4   0
# f_raw_s_1/S_D_0169_keypoints            0   4   0
# f_raw_s_1/S_D_0170_keypoints            0   4   0
# f_raw_s_1/S_D_0171_keypoints            0   6   0
# f_raw_s_1/S_D_0172_keypoints            0   6   0
# f_raw_s_1/S_D_0173_keypoints            0   6   0
# f_raw_s_1/S_D_0174_keypoints            0   3   0
# f_raw_s_1/S_D_0175_resized_keypoints    0   4   0
# f_raw_s_1/S_D_0176_keypoints            0   6   0
# f_raw_s_1/S_D_0177_keypoints            0   4   0
# f_raw_s_1/S_D_0178_keypoints            0   3   0
# f_raw_s_1/S_D_0179_keypoints            0   3   0
# f_raw_s_1/S_D_0180_keypoints            0   1   0
# f_raw_s_1/S_D_0181_keypoints            0   1   0
# f_raw_s_1/S_D_0182_keypoints            0   4   0
# f_raw_s_1/S_D_0183_keypoints            0   4   0
# f_raw_s_1/S_D_0184_keypoints            0   5   0
# f_raw_s_1/S_D_0185_keypoints            0   5   0
# f_raw_s_1/S_D_0186_keypoints            0   6   0
# f_raw_s_1/S_D_0187_resized_keypoints    0   4   0
# f_raw_s_1/S_D_0188_keypoints            0   6   0
# f_raw_s_1/S_D_0189_keypoints            0   6   0
# f_raw_s_1/S_D_0190_keypoints            0   5   0
# f_raw_s_1/S_D_0191_keypoints            0   5   0
# f_raw_s_1/S_D_0192_keypoints            0   3   0
# f_raw_s_1/S_D_0193_keypoints            0   3   0
# f_raw_s_1/S_D_0194_keypoints            0   6   0
# f_raw_s_1/S_D_0195_keypoints            0   4   0
# f_raw_s_1/S_D_0196_keypoints            0   2   0
# f_raw_s_1/S_D_0197_keypoints            0   2   0
# f_raw_s_1/S_D_0198_keypoints            0   8   0
# f_raw_s_1/S_D_0199_resized_keypoints    0   6   0
# f_raw_s_1/S_D_0200_keypoints            0   6   0
# f_raw_s_1/S_D_0201_keypoints            0   6   0
# f_raw_s_1/S_D_0202_keypoints            0   8   0
# f_raw_s_1/S_D_0203_keypoints            0   8   0
# f_raw_s_1/S_D_0205_keypoints            0   5   0
# f_raw_s_1/S_D_0206_keypoints            0   3   0
# f_raw_s_1/S_D_0207_keypoints            0   6   0
# f_raw_s_1/S_D_0208_keypoints            0   6   0
# f_raw_s_1/S_D_0209_keypoints            0   7   0
# f_raw_s_1/S_D_0210_keypoints            0   4   0
# f_raw_s_1/S_D_0211_resized_keypoints    0   4   0
# f_raw_s_1/S_D_0212_keypoints            0   6   0
# f_raw_s_1/S_D_0213_keypoints            0   5   0
# f_raw_s_1/S_D_0214_keypoints            0   5   0
# f_raw_s_1/S_D_0215_keypoints            0   6   0
# f_raw_s_1/S_D_0216_keypoints            0   6   0
# f_raw_s_1/S_D_0218_keypoints            0   5   0
# f_raw_s_1/S_D_0219_keypoints            0  35   0
# f_raw_s_1/S_D_0220_keypoints            0   6   0
# f_raw_s_1/S_D_0221_keypoints            0   6   0
# f_raw_s_1/S_D_0222_keypoints            0   6   0
# f_raw_s_1/S_D_0223_resized_keypoints    0   6   0
# f_raw_s_1/S_D_0224_keypoints            0   4   0
# f_raw_s_1/S_D_0225_keypoints            0   5   0
# f_raw_s_1/S_D_0226_keypoints            0   8   0
# f_raw_s_1/S_D_0227_keypoints            0   6   0
# f_raw_s_1/S_D_0229_resized_keypoints    0   6   0
# f_raw_s_1/S_D_0230_resized_keypoints    0   6   0
# f_raw_s_1/S_D_0231_resized_keypoints    0   8   0
# f_raw_s_1/S_D_0233_resized_keypoints    0   6   0
# f_raw_s_1/S_D_0234_resized_keypoints    0   8   0
# f_raw_s_1/S_D_0235_resized_keypoints    0   6   0
# f_raw_s_1/S_D_0236_keypoints            0   6   0
# f_raw_s_1/S_D_0237_resized_keypoints    0   5   0
# f_raw_s_1/S_D_0238_resized_keypoints    0   4   0
# f_raw_s_1/S_D_0239_resized_keypoints    0   6   0
# f_raw_s_1/S_D_0240_resized_keypoints    0   6   0
# f_raw_s_1/S_D_0241_resized_keypoints    0   8   0
# f_raw_s_1/S_D_0242_keypoints            0   6   0
# f_raw_s_1/S_D_0243_keypoints            0   8   0
# f_raw_s_1/S_D_0244_keypoints            0   8   0
# f_raw_s_1/S_D_0245_keypoints            0   8   0
# f_raw_s_1/S_D_0246_keypoints            0   8   0
# f_raw_s_1/S_D_0247_resized_keypoints    0   4   0
# f_raw_s_1/S_D_0248_keypoints            0   6   0
# f_raw_s_1/S_D_0249_keypoints            0   6   0
# f_raw_s_1/S_D_0250_keypoints            0  10   0
# f_raw_s_1/S_D_0251_keypoints            0   8   0
# f_raw_s_1/S_D_0252_keypoints            0   8   0
# f_raw_s_1/S_D_0253_keypoints            0   6   0
# f_raw_s_1/S_D_0254_keypoints            0   8   0
# f_raw_s_1/S_D_0255_keypoints            0   5   0
# f_raw_s_1/S_D_0256_keypoints            0   3   0
# f_raw_s_1/S_D_0257_keypoints            0  10   0
# f_raw_s_1/S_D_0258_keypoints            0   2   0

# %% [markdown]
# ## 3. Split train / val / test
# > El split se hace **por video** (usando meta.csv) para evitar data leakage — ventanas del mismo video no pueden estar en train y test a la vez.

# %%
videos = meta["video"].unique()

# Split por video
train_vids, test_vids = train_test_split(videos, test_size=TEST_SIZE, random_state=SEED)
train_vids, val_vids  = train_test_split(train_vids, test_size=VAL_SIZE/(1-TEST_SIZE), random_state=SEED)

train_idx = meta[meta["video"].isin(train_vids)].index.values
val_idx   = meta[meta["video"].isin(val_vids)].index.values
test_idx  = meta[meta["video"].isin(test_vids)].index.values

X_train, y_train = X[train_idx], y[train_idx]
X_val,   y_val   = X[val_idx],   y[val_idx]
X_test,  y_test  = X[test_idx],  y[test_idx]

print(f"Train : {len(X_train):4d} ventanas ({len(train_vids)} videos)")
print(f"Val   : {len(X_val):4d} ventanas ({len(val_vids)} videos)")
print(f"Test  : {len(X_test):4d} ventanas ({len(test_vids)} videos)")
# Out:
# Train : 2443 ventanas (253 videos)
# Val   :  759 ventanas (73 videos)
# Test  :  457 ventanas (37 videos)

# %% [markdown]
# ## 4. Dataset y DataLoader

# %%
class FallDataset(Dataset):
    def __init__(self, X, y):
        self.X = torch.tensor(X, dtype=torch.float32)
        self.y = torch.tensor(y, dtype=torch.long)

    def __len__(self):
        return len(self.y)

    def __getitem__(self, idx):
        return self.X[idx], self.y[idx]


# Class weights para manejar el desbalance
class_counts = np.bincount(y_train)
class_weights = 1.0 / class_counts
class_weights = class_weights / class_weights.sum() * N_CLASSES  # normalizar
sample_weights = class_weights[y_train]

sampler = WeightedRandomSampler(
    weights=sample_weights,
    num_samples=len(y_train),
    replacement=True
)

train_ds = FallDataset(X_train, y_train)
val_ds   = FallDataset(X_val,   y_val)
test_ds  = FallDataset(X_test,  y_test)

train_loader = DataLoader(train_ds, batch_size=BATCH_SIZE, sampler=sampler)
val_loader   = DataLoader(val_ds,   batch_size=BATCH_SIZE, shuffle=False)
test_loader  = DataLoader(test_ds,  batch_size=BATCH_SIZE, shuffle=False)

print(f"Class weights: Normal={class_weights[0]:.3f} | Caída={class_weights[1]:.3f} | Post-caída={class_weights[2]:.3f}")
# Out:
# Class weights: Normal=0.421 | Caída=0.540 | Post-caída=2.039

# %% [markdown]
# ## 5. Modelo LSTM

# %%
class FallLSTM(nn.Module):
    def __init__(self, input_size, hidden_size, num_layers, num_classes, dropout):
        super().__init__()
        self.lstm = nn.LSTM(
            input_size=input_size,
            hidden_size=hidden_size,
            num_layers=num_layers,
            batch_first=True,
            dropout= dropout if num_layers > 1 else 0,
            bidirectional=False,
        )
        self.dropout = nn.Dropout(dropout)
        self.fc = nn.Linear(hidden_size, num_classes)

    def forward(self, x):
        # x: (batch, seq_len, input_size)
        out, _ = self.lstm(x)       # (batch, seq_len, hidden)
        out = out[:, -1, :]         # último timestep
        out = self.dropout(out)
        return self.fc(out)         # (batch, num_classes)


model = FallLSTM(
    input_size=N_FEATURES,
    hidden_size=HIDDEN_SIZE,
    num_layers=NUM_LAYERS,
    num_classes=N_CLASSES,
    dropout=DROPOUT,
).to(DEVICE)

print(model)
total_params = sum(p.numel() for p in model.parameters() if p.requires_grad)
print(f"\nParámetros entrenables: {total_params:,}")
# Out:
# FallLSTM(
#   (lstm): LSTM(68, 128, num_layers=2, batch_first=True, dropout=0.3)
#   (dropout): Dropout(p=0.3, inplace=False)
#   (fc): Linear(in_features=128, out_features=3, bias=True)
# )
#
# Parámetros entrenables: 233,859

# %% [markdown]
# ## 6. Entrenamiento

# %%
weights_tensor = torch.tensor(class_weights, dtype=torch.float32).to(DEVICE)
criterion = nn.CrossEntropyLoss(weight=weights_tensor)
optimizer = torch.optim.Adam(model.parameters(), lr=LR)
scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, patience=5, factor=0.5)

def run_epoch(loader, train=True):
    model.train() if train else model.eval()
    total_loss, correct, total = 0, 0, 0
    with torch.set_grad_enabled(train):
        for xb, yb in loader:
            xb, yb = xb.to(DEVICE), yb.to(DEVICE)
            preds = model(xb)
            loss = criterion(preds, yb)
            if train:
                optimizer.zero_grad()
                loss.backward()
                optimizer.step()
            total_loss += loss.item() * len(yb)
            correct    += (preds.argmax(1) == yb).sum().item()
            total      += len(yb)
    return total_loss / total, correct / total

history = {"train_loss": [], "val_loss": [], "train_acc": [], "val_acc": []}
best_val_loss   = float("inf")
best_model_path = DATA_DIR / "best_model.pt"
patience_counter = 0

for epoch in range(1, EPOCHS + 1):
    tr_loss, tr_acc = run_epoch(train_loader, train=True)
    vl_loss, vl_acc = run_epoch(val_loader,   train=False)
    scheduler.step(vl_loss)

    history["train_loss"].append(tr_loss)
    history["val_loss"].append(vl_loss)
    history["train_acc"].append(tr_acc)
    history["val_acc"].append(vl_acc)

    if vl_loss < best_val_loss:
        best_val_loss = vl_loss
        patience_counter = 0
        torch.save(model.state_dict(), best_model_path)
        saved = "✅"
    else:
        patience_counter += 1
        saved = f"(patience {patience_counter}/{PATIENCE_ES})"

    if epoch % 5 == 0 or epoch == 1:
        print(f"Epoch {epoch:3d}/{EPOCHS} | "
              f"Train loss: {tr_loss:.4f} acc: {tr_acc:.3f} | "
              f"Val loss: {vl_loss:.4f} acc: {vl_acc:.3f} {saved}")

    if patience_counter >= PATIENCE_ES:
        print(f"\n⏹  Early stopping en época {epoch}")
        break

# Recortar history al número real de épocas
actual_epochs = len(history["train_loss"])
print(f"\nMejor val_loss: {best_val_loss:.4f} | Épocas entrenadas: {actual_epochs}")
print(f"Mejor modelo guardado en: {best_model_path}")
# Out:
# Epoch   1/50 | Train loss: 0.5919 acc: 0.549 | Val loss: 0.8331 acc: 0.466 ✅
# Epoch   5/50 | Train loss: 0.3142 acc: 0.842 | Val loss: 0.2711 acc: 0.893 (patience 1/10)
# Epoch  10/50 | Train loss: 0.1434 acc: 0.928 | Val loss: 0.2353 acc: 0.885 (patience 1/10)
# Epoch  15/50 | Train loss: 0.1285 acc: 0.935 | Val loss: 0.6098 acc: 0.736 (patience 4/10)
# Epoch  20/50 | Train loss: 0.0826 acc: 0.953 | Val loss: 0.1343 acc: 0.943 ✅
# Epoch  25/50 | Train loss: 0.0724 acc: 0.956 | Val loss: 0.1122 acc: 0.939 ✅
# Epoch  30/50 | Train loss: 0.0839 acc: 0.949 | Val loss: 0.2068 acc: 0.899 (patience 5/10)
# Epoch  35/50 | Train loss: 0.1023 acc: 0.929 | Val loss: 0.1569 acc: 0.906 (patience 4/10)
# Epoch  40/50 | Train loss: 0.0701 acc: 0.955 | Val loss: 0.1031 acc: 0.946 ✅
# Epoch  45/50 | Train loss: 0.0607 acc: 0.961 | Val loss: 0.1085 acc: 0.938 (patience 5/10)
# Epoch  50/50 | Train loss: 0.0575 acc: 0.961 | Val loss: 0.1216 acc: 0.945 (patience 4/10)
#
# Mejor val_loss: 0.0912 | Épocas entrenadas: 50
# Mejor modelo guardado en: lstm_data\best_model.pt

# %% [markdown]
# ## 7. Curvas de entrenamiento

# %%
fig, axes = plt.subplots(1, 2, figsize=(14, 5))

epochs_range = range(1, actual_epochs + 1)

axes[0].plot(epochs_range, history["train_loss"], label="Train", color="#2196F3")
axes[0].plot(epochs_range, history["val_loss"],   label="Val",   color="#F44336")
axes[0].set_title("Loss")
axes[0].set_xlabel("Época")
axes[0].set_ylabel("CrossEntropy Loss")
axes[0].legend()
axes[0].grid(alpha=0.3)

axes[1].plot(epochs_range, history["train_acc"], label="Train", color="#2196F3")
axes[1].plot(epochs_range, history["val_acc"],   label="Val",   color="#F44336")
axes[1].set_title("Accuracy")
axes[1].set_xlabel("Época")
axes[1].set_ylabel("Accuracy")
axes[1].legend()
axes[1].grid(alpha=0.3)

plt.tight_layout()
plt.show()

# %% [markdown]
# ## 8. Evaluación en test set

# %%
# Cargar el mejor modelo
model.load_state_dict(torch.load(best_model_path, map_location=DEVICE))
model.eval()

all_preds, all_labels = [], []
with torch.no_grad():
    for xb, yb in test_loader:
        preds = model(xb.to(DEVICE)).argmax(1).cpu().numpy()
        all_preds.extend(preds)
        all_labels.extend(yb.numpy())

all_preds  = np.array(all_preds)
all_labels = np.array(all_labels)

print("Classification Report:")
print(classification_report(all_labels, all_preds, target_names=LABEL_NAMES))

# Matriz de confusión
cm = confusion_matrix(all_labels, all_preds)

fig, axes = plt.subplots(1, 2, figsize=(14, 5))

# Conteos absolutos
disp = ConfusionMatrixDisplay(cm, display_labels=LABEL_NAMES)
disp.plot(ax=axes[0], colorbar=False, cmap="Blues")
axes[0].set_title("Matriz de confusión (conteos)")

# Normalizada
cm_norm = cm.astype(float) / cm.sum(axis=1, keepdims=True)
disp_norm = ConfusionMatrixDisplay(np.round(cm_norm, 2), display_labels=LABEL_NAMES)
disp_norm.plot(ax=axes[1], colorbar=False, cmap="Blues")
axes[1].set_title("Matriz de confusión (normalizada)")

plt.tight_layout()
plt.show()
# Out:
# Classification Report:
#                 precision    recall  f1-score   support
#
#    Normal (-1)       0.99      0.99      0.99       286
#      Caída (0)       0.98      0.95      0.96       137
# Post-caída (1)       0.85      0.97      0.90        34
#
#       accuracy                           0.98       457
#      macro avg       0.94      0.97      0.95       457
#   weighted avg       0.98      0.98      0.98       457

# %%
# Métricas por clase
from sklearn.metrics import precision_recall_fscore_support

precision, recall, f1, support = precision_recall_fscore_support(
    all_labels, all_preds, average=None
)

metrics_df = pd.DataFrame({
    "Clase": LABEL_NAMES,
    "Precision": precision.round(3),
    "Recall":    recall.round(3),
    "F1":        f1.round(3),
    "Support":   support,
})
print(metrics_df.to_string(index=False))

# Gráfico de métricas por clase
fig, ax = plt.subplots(figsize=(10, 4))
x = np.arange(N_CLASSES)
width = 0.25
ax.bar(x - width, precision, width, label="Precision", color="#2196F3")
ax.bar(x,         recall,    width, label="Recall",    color="#4CAF50")
ax.bar(x + width, f1,        width, label="F1",        color="#FF9800")
ax.set_xticks(x)
ax.set_xticklabels(LABEL_NAMES)
ax.set_ylim(0, 1.1)
ax.set_title("Precision / Recall / F1 por clase")
ax.legend()
ax.grid(axis="y", alpha=0.3)
plt.tight_layout()
plt.show()
# Out:
#          Clase  Precision  Recall    F1  Support
#    Normal (-1)      0.993   0.990 0.991      286
#      Caída (0)      0.977   0.949 0.963      137
# Post-caída (1)      0.846   0.971 0.904       34

# %%
# ── Evaluación en URFALL (prueba de generalización) ───────────────────────────
urfall_csv_files = sorted(Path("Urfall/keypoints").glob("*.csv"))

urfall_sequences, urfall_labels = [], []

for csv_path in urfall_csv_files:
    df = pd.read_csv(csv_path).sort_values("frame").reset_index(drop=True)
    video_name = f"URFALL/{csv_path.stem}"
    seqs, labs, _ = build_sequences_from_df(
        df, WINDOW, STRIDE, MIN_VALID, video_name, feat_cols, FEATURE_MODE
    )
    urfall_sequences.extend(seqs)
    urfall_labels.extend(labs)

X_urfall = np.array(urfall_sequences, dtype=np.float32)
y_urfall = np.array([LABEL_MAP[l] for l in urfall_labels], dtype=np.int64)

print(f"URFALL — ventanas: {len(y_urfall)}")
print(f"  Normal (-1) : {(y_urfall==0).sum()}")
print(f"  Caída  (0)  : {(y_urfall==1).sum()}")
print(f"  Post   (1)  : {(y_urfall==2).sum()}")

model.load_state_dict(torch.load(best_model_path, map_location=DEVICE))
model.eval()

urfall_ds     = FallDataset(X_urfall, y_urfall)
urfall_loader = DataLoader(urfall_ds, batch_size=BATCH_SIZE, shuffle=False)

preds_urfall, labels_urfall = [], []
with torch.no_grad():
    for xb, yb in urfall_loader:
        preds = model(xb.to(DEVICE)).argmax(1).cpu().numpy()
        preds_urfall.extend(preds)
        labels_urfall.extend(yb.numpy())

preds_urfall  = np.array(preds_urfall)
labels_urfall = np.array(labels_urfall)

print("\n=== GENERALIZACIÓN — URFALL (nunca visto) ===")
print(classification_report(labels_urfall, preds_urfall, target_names=LABEL_NAMES))
# Out:
# URFALL — ventanas: 133
#   Normal (-1) : 56
#   Caída  (0)  : 54
#   Post   (1)  : 23
#
# === GENERALIZACIÓN — URFALL (nunca visto) ===
#                 precision    recall  f1-score   support
#
#    Normal (-1)       0.34      0.41      0.37        56
#      Caída (0)       0.83      0.37      0.51        54
# Post-caída (1)       0.19      0.35      0.25        23
#
#       accuracy                           0.38       133
#      macro avg       0.46      0.38      0.38       133
#   weighted avg       0.52      0.38      0.41       133

# %% [markdown]
# ## 9. Guardar modelo final

# %%
# Guardar con metadatos del modelo
checkpoint = {
    "model_state_dict": model.state_dict(),
    "hyperparams": {
        "input_size":  N_FEATURES,
        "hidden_size": HIDDEN_SIZE,
        "num_layers":  NUM_LAYERS,
        "num_classes": N_CLASSES,
        "dropout":     DROPOUT,
        "window":      WINDOW,
    },
    "label_map":   LABEL_MAP,
    "label_names": LABEL_NAMES,
}
save_path = DATA_DIR / "fall_lstm_final.pt"
torch.save(checkpoint, save_path)
print(f"Modelo guardado en: {save_path}")
# Out:
# Modelo guardado en: lstm_data\fall_lstm_final.pt

# %%
# # %% [markdown]
# # ## Experimento: Selección óptima de subconjunto FallVision
# # Entrena N veces con diferentes subconjuntos aleatorios de FallVision
# # y compara métricas en test interno y URFALL.

# # %%
# import random
# import torch
# import torch.nn as nn
# import numpy as np
# import pandas as pd
# from pathlib import Path
# from torch.utils.data import DataLoader, WeightedRandomSampler
# from sklearn.model_selection import train_test_split
# from sklearn.metrics import f1_score, classification_report

# # ── Configuración del experimento ─────────────────────────────────────────────
# N_EXPERIMENTS    = 100     # número de experimentos
# N_FALLVISION     = 15    # videos de FallVision por experimento
# SEED_BASE        = 42
# EPOCHS_EXP       = 50    # épocas por experimento
# PATIENCE_EXP     = 10    # early stopping

# LE2I_DIRS = [
#     "Coffee_room/keypoints_tunned",
#     "Home_room/keypoints_tunned",
#     #"Urfall/keypoints_train",
# ]
# FALLVISION_DIR  = Path("Fall_vision/keypoints/")
# URFALL_TEST_DIR = Path("Urfall/keypoints")  # para generalización

# # ──────────────────────────────────────────────────────────────────────────────

# all_fallvision_csvs = sorted(FALLVISION_DIR.glob("*.csv"))
# print(f"Total CSVs FallVision disponibles: {len(all_fallvision_csvs)}")

# def build_dataset(le2i_dirs, fallvision_subset, feat_cols, mode):
#     """Construye secuencias combinando LE2I y un subconjunto de FallVision."""
#     csv_files = []
#     for d in le2i_dirs:
#         csv_files.extend(sorted(Path(d).glob("*.csv")))
#     csv_files.extend(fallvision_subset)

#     all_sequences, all_labels, all_meta = [], [], []
#     for csv_path in csv_files:
#         df = pd.read_csv(csv_path).sort_values("frame").reset_index(drop=True)
#         video_name = f"{csv_path.parent.parent.name}/{csv_path.stem}"
#         seqs, labs, meta = build_sequences_from_df(
#             df, WINDOW, STRIDE, MIN_VALID, video_name, feat_cols, FEATURE_MODE
#         )
#         all_sequences.extend(seqs)
#         all_labels.extend(labs)
#         all_meta.extend(meta)

#     X     = np.array(all_sequences, dtype=np.float32)
#     y_raw = np.array(all_labels,    dtype=np.int8)
#     meta_df = pd.DataFrame(all_meta)
#     return X, y_raw, meta_df


# def train_and_evaluate(X, y_raw, meta_df, seed):
#     """Entrena el modelo y retorna métricas en test interno y URFALL."""
#     y = np.array([LABEL_MAP[l] for l in y_raw], dtype=np.int64)

#     # Split por video
#     videos = meta_df["video"].unique()
#     train_vids, test_vids = train_test_split(videos, test_size=TEST_SIZE, random_state=seed)
#     train_vids, val_vids  = train_test_split(train_vids, test_size=VAL_SIZE/(1-TEST_SIZE), random_state=seed)

#     train_idx = meta_df[meta_df["video"].isin(train_vids)].index.values
#     val_idx   = meta_df[meta_df["video"].isin(val_vids)].index.values
#     test_idx  = meta_df[meta_df["video"].isin(test_vids)].index.values

#     X_train, y_train = X[train_idx], y[train_idx]
#     X_val,   y_val   = X[val_idx],   y[val_idx]
#     X_test,  y_test  = X[test_idx],  y[test_idx]

#     # Class weights
#     class_counts  = np.bincount(y_train)
#     class_weights = 1.0 / class_counts
#     class_weights = class_weights / class_weights.sum() * N_CLASSES
#     sample_weights = class_weights[y_train]

#     sampler = WeightedRandomSampler(sample_weights, len(y_train), replacement=True)

#     train_loader = DataLoader(FallDataset(X_train, y_train), batch_size=BATCH_SIZE, sampler=sampler)
#     val_loader   = DataLoader(FallDataset(X_val,   y_val),   batch_size=BATCH_SIZE, shuffle=False)
#     test_loader  = DataLoader(FallDataset(X_test,  y_test),  batch_size=BATCH_SIZE, shuffle=False)

#     # Modelo nuevo por experimento
#     torch.manual_seed(seed)
#     exp_model = FallLSTM(N_FEATURES, HIDDEN_SIZE, NUM_LAYERS, N_CLASSES, DROPOUT).to(DEVICE)
#     weights_tensor = torch.tensor(class_weights, dtype=torch.float32).to(DEVICE)
#     criterion = nn.CrossEntropyLoss(weight=weights_tensor)
#     optimizer = torch.optim.Adam(exp_model.parameters(), lr=LR)
#     scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, patience=5, factor=0.5)

#     best_val_loss    = float("inf")
#     best_state       = None
#     patience_counter = 0

#     for epoch in range(1, EPOCHS_EXP + 1):
#         # Train
#         exp_model.train()
#         for xb, yb in train_loader:
#             xb, yb = xb.to(DEVICE), yb.to(DEVICE)
#             loss = criterion(exp_model(xb), yb)
#             optimizer.zero_grad(); loss.backward(); optimizer.step()

#         # Val
#         exp_model.eval()
#         val_loss = 0
#         with torch.no_grad():
#             for xb, yb in val_loader:
#                 val_loss += criterion(exp_model(xb.to(DEVICE)), yb.to(DEVICE)).item() * len(yb)
#         val_loss /= len(y_val)
#         scheduler.step(val_loss)

#         if val_loss < best_val_loss:
#             best_val_loss = val_loss
#             best_state = {k: v.clone() for k, v in exp_model.state_dict().items()}
#             patience_counter = 0
#         else:
#             patience_counter += 1
#             if patience_counter >= PATIENCE_EXP:
#                 break

#     # Cargar mejor estado
#     exp_model.load_state_dict(best_state)
#     exp_model.eval()

#     def get_preds(loader):
#         preds, labels = [], []
#         with torch.no_grad():
#             for xb, yb in loader:
#                 p = exp_model(xb.to(DEVICE)).argmax(1).cpu().numpy()
#                 preds.extend(p); labels.extend(yb.numpy())
#         return np.array(preds), np.array(labels)

#     # Métricas test interno
#     preds_test, labels_test = get_preds(test_loader)
#     f1_test = f1_score(labels_test, preds_test, average=None, zero_division=0)

#     # Métricas URFALL
#     urfall_seqs, urfall_labs = [], []
#     for csv_path in sorted(URFALL_TEST_DIR.glob("*.csv")):
#         df = pd.read_csv(csv_path).sort_values("frame").reset_index(drop=True)
#         seqs, labs, _ = build_sequences_from_df(
#             df, WINDOW, STRIDE, MIN_VALID, csv_path.stem, feat_cols, FEATURE_MODE
#         )
#         urfall_seqs.extend(seqs); urfall_labs.extend(labs)

#     X_ur = np.array(urfall_seqs, dtype=np.float32)
#     y_ur = np.array([LABEL_MAP[l] for l in urfall_labs], dtype=np.int64)
#     ur_loader = DataLoader(FallDataset(X_ur, y_ur), batch_size=BATCH_SIZE, shuffle=False)
#     preds_ur, labels_ur = get_preds(ur_loader)
#     f1_ur = f1_score(labels_ur, preds_ur, average=None, zero_division=0)

#     return {
#         "f1_test_normal": f1_test[0], "f1_test_fall": f1_test[1], "f1_test_post": f1_test[2],
#         "f1_ur_normal":   f1_ur[0],   "f1_ur_fall":   f1_ur[1],   "f1_ur_post":   f1_ur[2],
#         "epochs": epoch,
#     }


# # ── Correr experimentos ───────────────────────────────────────────────────────
# results = []
# best_score    = 0
# best_exp_csvs = None

# for exp in range(N_EXPERIMENTS):
#     seed = SEED_BASE + exp
#     random.seed(seed)
#     selected = random.sample(all_fallvision_csvs, N_FALLVISION)

#     print(f"\n{'─'*55}")
#     print(f"Experimento {exp+1}/{N_EXPERIMENTS} | seed={seed} | FallVision: {N_FALLVISION} videos")

#     X, y_raw, meta_df = build_dataset(LE2I_DIRS, selected, feat_cols, FEATURE_MODE)
#     metrics = train_and_evaluate(X, y_raw, meta_df, seed)
#     metrics["exp"] = exp + 1
#     metrics["seed"] = seed

#     # Score que prioriza valores altos Y equilibrados
#     f1_test = metrics["f1_test_fall"]
#     f1_ur   = metrics["f1_ur_fall"]
#     if f1_test + f1_ur > 0:
#         harmonic     = 2 * (f1_test * f1_ur) / (f1_test + f1_ur)
#         arithmetic   = (f1_test + f1_ur) / 2
#         balanced_score = harmonic * arithmetic
#     else:
#         balanced_score = 0
#     metrics["balanced_score"] = balanced_score

#     results.append(metrics)

#     print(f"  Test interno — F1 Caída: {f1_test:.3f}")
#     print(f"  URFALL       — F1 Caída: {f1_ur:.3f}")
#     print(f"  Score balance          : {balanced_score:.3f}  ← criterio de selección")

#     if balanced_score > best_score:
#         best_score    = balanced_score
#         best_exp_csvs = selected
#         best_seed     = seed
#         best_f1_ur    = f1_ur

# # ── Resumen ───────────────────────────────────────────────────────────────────
# print(f"\n{'═'*55}")
# print(f"RESUMEN DE EXPERIMENTOS\n")
# results_df = pd.DataFrame(results)
# print(results_df[[
#     "exp", "seed", "epochs",
#     "f1_test_fall", "f1_ur_fall", "balanced_score"
# ]].sort_values("balanced_score", ascending=False).to_string(index=False))

# print(f"\nMejor score balanceado: exp={results_df.loc[results_df['balanced_score'].idxmax(), 'exp']} "
#       f"Score={best_score:.3f} | F1 test={results_df.loc[results_df['balanced_score'].idxmax(), 'f1_test_fall']:.3f} "
#       f"| F1 URFALL={best_f1_ur:.3f} (seed={best_seed})")


# # ── Guardar el mejor subconjunto de FallVision ────────────────────────────────
# import shutil

# best_subset_dir = Path("Fall_vision/keypoints_best_subset")
# best_subset_dir.mkdir(exist_ok=True)

# for csv_path in best_exp_csvs:
#     shutil.copy(csv_path, best_subset_dir / csv_path.name)

# print(f"✅ Mejor subconjunto guardado en: {best_subset_dir}")
# print(f"   Videos copiados : {len(best_exp_csvs)}")
# print(f"   F1 URFALL        : {best_f1_ur:.3f} (seed={best_seed})")
# print(f"\nPara usarlo en entrenamiento agrega a KEYPOINTS_DIRS:")
# print(f'   "Fall_vision/keypoints_best_subset"')

# %%
import pandas as pd
df = pd.read_csv("Fall_vision/f_raw_s_1/keypoints/S_D_0002_resized_keypoints.csv")
print([c for c in df.columns if "kp_23" in c or "kp_25" in c])
# Out:
# ['kp_23_x', 'kp_23_y', 'kp_25_x', 'kp_25_y']
